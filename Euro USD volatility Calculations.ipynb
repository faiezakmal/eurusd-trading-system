# %%
import numpy as np

# log return with np diff
lprice = np.log(sp['Close'])
ret = np.diff(lprice)
# or
#Compute log returns: Log return = log(Close_t / Close_(t-1))
sp['log_return'] = np.log(sp['Close'] / sp['Close'].shift(1))

# Drop rows with NaN values (the first row will have NaN due to the shift)
sp.dropna(subset=['log_return'], inplace=True)

# Check if the 'log_return' column is created correctly
print(sp.head())

# log returns with pandas
ret_pandas = np.log(sp['Close']).diff()
# diff provided by pandas returns an array with the same shape as the original
# it starts with NaN
# while np.diff returns an array with one less element
ret_pandas

# we can plug the result of pandas into the dataframe
sp['log_return'] = ret_pandas
sp
# Out:
#                  Date         Open         High          Low        Close  \
# 3 2025-01-20 00:04:00 1.0279000000 1.0279000000 1.0277000000 1.0277000000
# 4 2025-01-20 00:05:00 1.0277000000 1.0279000000 1.0277000000 1.0278000000
# 5 2025-01-20 00:06:00 1.0278000000 1.0281000000 1.0278000000 1.0280000000
# 6 2025-01-20 00:07:00 1.0280000000 1.0282000000 1.0279000000 1.0282000000
# 7 2025-01-20 00:08:00 1.0282000000 1.0282000000 1.0280000000 1.0281000000
#
#      log_return
# 3 -0.0001945904
# 4  0.0000972999
# 5  0.0001945715
# 6  0.0001945336
# 7 -0.0000972621
#                      Date         Open         High          Low        Close  \
# 3     2025-01-20 00:04:00 1.0279000000 1.0279000000 1.0277000000 1.0277000000
# 4     2025-01-20 00:05:00 1.0277000000 1.0279000000 1.0277000000 1.0278000000
# 5     2025-01-20 00:06:00 1.0278000000 1.0281000000 1.0278000000 1.0280000000
# 6     2025-01-20 00:07:00 1.0280000000 1.0282000000 1.0279000000 1.0282000000
# 7     2025-01-20 00:08:00 1.0282000000 1.0282000000 1.0280000000 1.0281000000
# ...                   ...          ...          ...          ...          ...
# 93619 2025-04-18 20:51:00 1.1391000000 1.1391000000 1.1390000000 1.1391000000
# 93620 2025-04-18 20:52:00 1.1391000000 1.1392000000 1.1391000000 1.1392000000
# 93621 2025-04-18 20:53:00 1.1392000000 1.1393000000 1.1392000000 1.1392000000
# 93622 2025-04-18 20:54:00 1.1392000000 1.1392000000 1.1392000000 1.1392000000
# 93623 2025-04-18 20:55:00 1.1391000000 1.1392000000 1.1391000000 1.1391000000
#
#          log_return
# 3               NaN
# 4      0.0000972999
# 5      0.0001945715
# 6      0.0001945336
# 7     -0.0000972621
# ...             ...
# 93619  0.0000000000
# 93620  0.0000877848
# 93621  0.0000000000
# 93622  0.0000000000
# 93623 -0.0000877848
#
# [93621 rows x 6 columns]

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.filters.hp_filter import hpfilter

# STEP 0: Load data and ensure 'Close' has a datetime index
sp = pd.read_csv("Eurousd.csv", parse_dates=['Date'], index_col='Date')  # Assuming 'Date' column exists
close = sp['Close'].dropna()

# STEP 1: Differencing to remove trend
diff_close = close.diff().dropna()

# STEP 2: Apply HP filter to extract trend and cyclical components
trend, cyclical = hpfilter(diff_close, lamb=1600)

# STEP 3: Deseasonalize using intraday seasonal mean removal
def deseasonalize_intraday_returns(df, return_col='returns'):
    df = df.copy()
    df.index = pd.to_datetime(df.index)
    df['time'] = df.index.time
    seasonal_pattern = df.groupby('time')[return_col].mean()
    df['seasonal_mean'] = df['time'].map(seasonal_pattern)
    df['deseasonalized'] = df[return_col] - df['seasonal_mean']
    return df['deseasonalized']

# Prepare input DataFrame for deseasonalization (fixing the index issue)
returns_df = pd.DataFrame({'returns': cyclical}, index=diff_close.index)
deseasonalized = deseasonalize_intraday_returns(returns_df, return_col='returns')

# Optional: Scaling the deseasonalized data
deseasonalized_scaled = (deseasonalized - deseasonalized.mean()) / deseasonalized.std()

# STEP 4: Calculate Realized Volatility (RV) using window and D (sampling interval)
D = 5  # Interval size (e.g., 5-minute returns)
window = 5  # Rolling window size for volatility calculation

# Calculate the squared returns (returns^2)
squared_returns = deseasonalized_scaled ** 2

# Calculate Realized Volatility (RV) using a rolling window and D
sp['squared_return'] = squared_returns
sp['realized_vol_D'] = sp['squared_return'].rolling(window=window).sum() / D
sp['realized_vol_D'] = np.sqrt(sp['realized_vol_D'])

# STEP 5: ADF Test function
def run_adf(series, label):
    result = adfuller(series.dropna())
    print(f"ADF Test - {label}")
    print(f"ADF Statistic: {result[0]:.4f}")
    print(f"p-value: {result[1]:.4f}")
    print(f"Critical Values: {result[4]}")
    print("-" * 50)

# Run ADF tests
run_adf(close, "Original Close")
run_adf(diff_close, "Differenced Close")
run_adf(cyclical, "HP Filter - Cyclical Component")
run_adf(deseasonalized, "Deseasonalized (Intraday Mean Removed)")
run_adf(deseasonalized_scaled, "Scaled Deseasonalized")
run_adf(sp['realized_vol_D'], "Realized Volatility (RV)")

# STEP 6: Plot all components
plt.figure(figsize=(14, 12))

# Plot 1: Original EUR/USD Close
plt.subplot(5, 1, 1)
plt.plot(close, label='Original Close')
plt.title("Original EUR/USD Close")
plt.legend()

# Plot 2: Differenced Close
plt.subplot(5, 1, 2)
plt.plot(diff_close, label='Differenced Close')
plt.title("Differenced Close")
plt.legend()

# Plot 3: HP Filter Cyclical Component
plt.subplot(5, 1, 3)
plt.plot(cyclical, label='HP Filter Cyclical Component')
plt.title("HP Filter - Cyclical Component")
plt.legend()

# Plot 4: Deseasonalized (Intraday Seasonality Removed)
plt.subplot(5, 1, 4)
plt.plot(deseasonalized, label='Deseasonalized (Intraday)', color='green')
plt.title("Deseasonalized (Intraday Seasonality Removed)")
plt.legend()

# Plot 5: Realized Volatility (RV)
plt.subplot(5, 1, 5)
plt.plot(sp['realized_vol_D'], label='Realized Volatility (RV)', color='red')
plt.title("Realized Volatility Based on Window and D")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-b718b51797e2>:9: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sp = pd.read_csv("Eurousd.csv", parse_dates=['Date'], index_col='Date')  # Assuming 'Date' column exists
# ADF Test - Original Close
# ADF Statistic: -0.0097
# p-value: 0.9577
# Critical Values: {'1%': np.float64(-3.430419894609131), '5%': np.float64(-2.8615708922987753), '10%': np.float64(-2.566786442893727)}
# --------------------------------------------------
# ADF Test - Differenced Close
# ADF Statistic: -37.4722
# p-value: 0.0000
# Critical Values: {'1%': np.float64(-3.4304198998389497), '5%': np.float64(-2.861570894610244), '10%': np.float64(-2.566786444124046)}
# --------------------------------------------------
# ADF Test - HP Filter - Cyclical Component
# ADF Statistic: -30.4089
# p-value: 0.0000
# Critical Values: {'1%': np.float64(-3.4304198975975027), '5%': np.float64(-2.861570893619572), '10%': np.float64(-2.566786443596744)}
# --------------------------------------------------
# ADF Test - Deseasonalized (Intraday Mean Removed)
# ADF Statistic: -31.3547
# p-value: 0.0000
# Critical Values: {'1%': np.float64(-3.4304198998389497), '5%': np.float64(-2.861570894610244), '10%': np.float64(-2.566786444124046)}
# --------------------------------------------------
# ADF Test - Scaled Deseasonalized
# ADF Statistic: -31.3547
# p-value: 0.0000
# Critical Values: {'1%': np.float64(-3.4304198998389497), '5%': np.float64(-2.861570894610244), '10%': np.float64(-2.566786444124046)}
# --------------------------------------------------
# ADF Test - Realized Volatility (RV)
# ADF Statistic: -21.0397
# p-value: 0.0000
# Critical Values: {'1%': np.float64(-3.43041990208054), '5%': np.float64(-2.8615708956009795), '10%': np.float64(-2.566786444651382)}
# --------------------------------------------------

# %% [markdown]
# | **Transformation**             | **ADF Statistic** | **p-value** | **Stationary?** | **Notes**                                           |
# | ------------------------------ | ----------------- | ----------- | --------------- | --------------------------------------------------- |
# | Original Close                 | -0.0097           | 0.9577      | ❌ No            | Strong trend; not suitable for modeling as-is       |
# | Differenced Close              | -37.4722          | 0.0000      | ✅ Yes           | First difference removed trend                      |
# | HP Filter (Cyclical Component) | -30.4089          | 0.0000      | ✅ Yes           | Short-term cycle is stationary                      |
# | Deseasonalized (Intraday Mean) | -31.3547          | 0.0000      | ✅ Yes           | Seasonal pattern removed                            |
# | Scaled Deseasonalized          | -31.3547          | 0.0000      | ✅ Yes           | Standardization doesn't affect stationarity         |
# | Realized Volatility (RV)       | -21.0397          | 0.0000      | ✅ Yes           | Volatility is stable; ready for volatility modeling |

# %%
from statsmodels.graphics.tsaplots import plot_acf
# STEP 7: Plot ACF of Deseasonalized Scaled Returns and Realized Volatility
plt.figure(figsize=(12, 6))

# ACF of Deseasonalized Scaled Returns
plt.subplot(1, 2, 1)
plot_acf(deseasonalized_scaled.dropna(), ax=plt.gca(), lags=40)
plt.title("ACF - Deseasonalized Scaled Returns")

# ACF of Realized Volatility
plt.subplot(1, 2, 2)
plot_acf(sp['realized_vol_D'].dropna(), ax=plt.gca(), lags=40)
plt.title("ACF - Realized Volatility")

plt.tight_layout()
plt.show()

# %%
import matplotlib.dates as mdates

# Find index of min and max RV
min_idx = sp['realized_vol_D'].idxmin()
max_idx = sp['realized_vol_D'].idxmax()
min_val = sp['realized_vol_D'].min()
max_val = sp['realized_vol_D'].max()

# Plot the entire RV time series
plt.figure(figsize=(14, 6))
plt.plot(sp['realized_vol_D'], label='Realized Volatility (RV)', color='red', linewidth=1.5)

# Highlight Min and Max points
plt.scatter(min_idx, min_val, color='blue', marker='v', s=100, label='Min RV')
plt.scatter(max_idx, max_val, color='black', marker='^', s=100, label='Max RV')

# Annotate points
plt.annotate(f'Min: {min_val:.4f}',
             xy=(min_idx, min_val),
             xytext=(min_idx, min_val + 0.01),
             textcoords='data',
             arrowprops=dict(facecolor='blue', arrowstyle='->', lw=1),
             fontsize=9,
             color='blue')

plt.annotate(f'Max: {max_val:.4f}',
             xy=(max_idx, max_val),
             xytext=(max_idx, max_val + 0.01),
             textcoords='data',
             arrowprops=dict(facecolor='black', arrowstyle='->', lw=1),
             fontsize=9,
             color='black')

# Improve aesthetics
plt.title("Realized Volatility (RV) with Min & Max Points", fontsize=14)
plt.xlabel("Date")
plt.ylabel("Realized Volatility")
plt.legend()
plt.grid(True)

# Improve x-axis formatting
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
plt.boxplot(sp['realized_vol_D'].dropna(), vert=True, patch_artist=True,
            boxprops=dict(facecolor='lightgreen', color='black'),
            medianprops=dict(color='black'),
            whiskerprops=dict(color='black'),
            capprops=dict(color='black'),
            flierprops=dict(markerfacecolor='red', marker='o', markersize=5, linestyle='none'))

plt.title('Boxplot of Realized Volatility (RV)', fontsize=14)
plt.ylabel('RV')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Drop NaNs from the RV series
rv_data = sp['realized_vol_D'].dropna()

# Compute quantiles
q1 = rv_data.quantile(0.01)
q25 = rv_data.quantile(0.25)
q50 = rv_data.quantile(0.50)
q75 = rv_data.quantile(0.75)
q99 = rv_data.quantile(0.99)

# Plot histogram
plt.figure(figsize=(10, 5))
plt.hist(rv_data, bins=50, color='lightgray', edgecolor='black', alpha=0.8)

# Overlay quantile lines
plt.axvline(q25, color='orange', linestyle='--', linewidth=2, label='25th Percentile')
plt.axvline(q50, color='blue', linestyle='--', linewidth=2, label='Median (50th)')
plt.axvline(q75, color='green', linestyle='--', linewidth=2, label='75th Percentile')

# Zoom into 1st to 99th percentile range
plt.xlim(q1, q99)

# Titles and labels
plt.title('Zoomed Histogram of Realized Volatility with Quantiles', fontsize=14)
plt.xlabel('Realized Volatility (RV)')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Drop NaN values from the realized_vol_D column
sp_cleaned = sp.dropna(subset=['realized_vol_D'])

# Create subplots for different lags
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Plot 1: Autocorrelation for lags 0 to 100
plot_acf(sp_cleaned['realized_vol_D'], lags=range(0, 101), ax=axes[0, 0], alpha=0.05)
axes[0, 0].set_title('Autocorrelation of Realized Volatility (Lags 0–100)')
axes[0, 0].set_xlabel('Lags')
axes[0, 0].set_ylabel('Autocorrelation')

# Plot 2: Autocorrelation for lags 0 to 1000
plot_acf(sp_cleaned['realized_vol_D'], lags=range(0, 1001), ax=axes[0, 1], alpha=0.05)
axes[0, 1].set_title('Autocorrelation of Realized Volatility (Lags 0–1000)')
axes[0, 1].set_xlabel('Lags')
axes[0, 1].set_ylabel('Autocorrelation')

# Plot 3: Autocorrelation for lags 0 to 4000
plot_acf(sp_cleaned['realized_vol_D'], lags=range(0, 4001), ax=axes[1, 0], alpha=0.05)
axes[1, 0].set_title('Autocorrelation of Realized Volatility (Lags 0–4000)')
axes[1, 0].set_xlabel('Lags')
axes[1, 0].set_ylabel('Autocorrelation')

# Plot 4: Autocorrelation for lags 0 to 10000
plot_acf(sp_cleaned['realized_vol_D'], lags=range(0, 10001), ax=axes[1, 1], alpha=0.05)
axes[1, 1].set_title('Autocorrelation of Realized Volatility (Lags 0–10000)')
axes[1, 1].set_xlabel('Lags')
axes[1, 1].set_ylabel('Autocorrelation')

# Layout adjustment
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.stats.diagnostic import acorr_ljungbox

# Clean the data
rv_data = sp['realized_vol_D'].dropna()

# Run Ljung-Box test for lags 1 to 100
lb_test_vol = acorr_ljungbox(rv_data, lags=range(1, 101), return_df=True)

# Set display format
pd.set_option('display.float_format', '{:.10f}'.format)
print(lb_test_vol)

# Plot p-values with better zoom
plt.figure(figsize=(12, 5))
plt.plot(lb_test_vol.index, lb_test_vol['lb_pvalue'], marker='o', linestyle='-', color='navy', label='p-value')

# Add significance threshold line at 0.05
plt.axhline(y=0.05, color='red', linestyle='--', linewidth=1, label='Significance Level (0.05)')

# Improved Zoom: Show range from 0 to 0.15
plt.ylim(0, 0.025)

# Plot styling
plt.title('Ljung-Box Test p-values (Zoomed: 0–0.15)', fontsize=14)
plt.xlabel('Lag', fontsize=12)
plt.ylabel('p-value', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#                lb_stat    lb_pvalue
# 1     92544.1607097487 0.0000000000
# 2    181975.1355171633 0.0000000000
# 3    266558.8248795982 0.0000000000
# 4    344979.5265893777 0.0000000000
# 5    416383.2272255628 0.0000000000
# ..                 ...          ...
# 96  1375290.1866232797 0.0000000000
# 97  1381532.4079131470 0.0000000000
# 98  1387745.4442762460 0.0000000000
# 99  1393919.6465441964 0.0000000000
# 100 1400046.1188686928 0.0000000000
#
# [100 rows x 2 columns]

# %%
# Out:
#                  Date         Open         High          Low        Close  \
# 2 2025-01-20 00:03:00 1.0282000000 1.0282000000 1.0279000000 1.0279000000
# 3 2025-01-20 00:04:00 1.0279000000 1.0279000000 1.0277000000 1.0277000000
# 4 2025-01-20 00:05:00 1.0277000000 1.0279000000 1.0277000000 1.0278000000
# 5 2025-01-20 00:06:00 1.0278000000 1.0281000000 1.0278000000 1.0280000000
# 6 2025-01-20 00:07:00 1.0280000000 1.0282000000 1.0279000000 1.0282000000
#
#      log_return
# 2 -0.0001945525
# 3 -0.0001945904
# 4  0.0000972999
# 5  0.0001945715
# 6  0.0001945336
#                      Date         Open         High          Low        Close  \
# 2     2025-01-20 00:03:00 1.0282000000 1.0282000000 1.0279000000 1.0279000000
# 3     2025-01-20 00:04:00 1.0279000000 1.0279000000 1.0277000000 1.0277000000
# 4     2025-01-20 00:05:00 1.0277000000 1.0279000000 1.0277000000 1.0278000000
# 5     2025-01-20 00:06:00 1.0278000000 1.0281000000 1.0278000000 1.0280000000
# 6     2025-01-20 00:07:00 1.0280000000 1.0282000000 1.0279000000 1.0282000000
# ...                   ...          ...          ...          ...          ...
# 93619 2025-04-18 20:51:00 1.1391000000 1.1391000000 1.1390000000 1.1391000000
# 93620 2025-04-18 20:52:00 1.1391000000 1.1392000000 1.1391000000 1.1392000000
# 93621 2025-04-18 20:53:00 1.1392000000 1.1393000000 1.1392000000 1.1392000000
# 93622 2025-04-18 20:54:00 1.1392000000 1.1392000000 1.1392000000 1.1392000000
# 93623 2025-04-18 20:55:00 1.1391000000 1.1392000000 1.1391000000 1.1391000000
#
#          log_return
# 2               NaN
# 3     -0.0001945904
# 4      0.0000972999
# 5      0.0001945715
# 6      0.0001945336
# ...             ...
# 93619  0.0000000000
# 93620  0.0000877848
# 93621  0.0000000000
# 93622  0.0000000000
# 93623 -0.0000877848
#
# [93622 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Ensure no NaNs in the relevant columns
# Calculate log returns and add to DataFrame
sp['log_return'] = np.log(sp['Close'] / sp['Close'].shift(1))

vol_log_df = sp[['realized_vol_D', 'log_return']].dropna()

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(vol_log_df['realized_vol_D'], vol_log_df['log_return'],
            alpha=0.5, color='darkorange', edgecolor='k', s=20)

plt.title('Scatter Plot: Realized Volatility vs Log Return ')
plt.xlabel('Realized Volatility')
plt.ylabel('Log Return')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.stats.diagnostic import acorr_ljungbox

# Set inline figure format for better resolution (for Jupyter)
# %config InlineBackend.figure_format = 'retina'

# Assuming 'sp' is your DataFrame and it contains a 'Close' price column
# Calculate log returns
sp['log_return'] = np.log(sp['Close'] / sp['Close'].shift(1))
ret = sp['log_return'].dropna()

# Create subplots for multiple ACF plots
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Plot 1: Autocorrelation for lags 10 to 100
plot_acf(ret, lags=range(10, 101), ax=axes[0, 0], alpha=0.05)
axes[0, 0].set_title('Autocorrelation of Log Returns (Lags 10–100)')
axes[0, 0].set_xlabel('Lags')
axes[0, 0].set_ylabel('Autocorrelation')
axes[0, 0].set_ylim([-0.1, 0.1])

# Plot 2: Autocorrelation for lags 10 to 1000
plot_acf(ret, lags=range(10, 1001), ax=axes[0, 1], alpha=0.05)
axes[0, 1].set_title('Autocorrelation of Log Returns (Lags 10–1000)')
axes[0, 1].set_xlabel('Lags')
axes[0, 1].set_ylabel('Autocorrelation')
axes[0, 1].set_ylim([-0.1, 0.1])

# Plot 3: Autocorrelation for lags 10 to 4000
plot_acf(ret, lags=range(10, 4001), ax=axes[1, 0], alpha=0.05)
axes[1, 0].set_title('Autocorrelation of Log Returns (Lags 10–4000)')
axes[1, 0].set_xlabel('Lags')
axes[1, 0].set_ylabel('Autocorrelation')
axes[1, 0].set_ylim([-0.1, 0.1])

# Plot 4: Autocorrelation for lags 10 to 10000
plot_acf(ret, lags=range(10, 10001), ax=axes[1, 1], alpha=0.05)
axes[1, 1].set_title('Autocorrelation of Log Returns (Lags 10–10000)')
axes[1, 1].set_xlabel('Lags')
axes[1, 1].set_ylabel('Autocorrelation')
axes[1, 1].set_ylim([-0.1, 0.1])

# Adjust layout
plt.tight_layout()
plt.show()

# Ljung-Box tests at various lags
ljung_box_results = {
    20: acorr_ljungbox(ret, lags=[20], return_df=True),
    100: acorr_ljungbox(ret, lags=[100], return_df=True),
    1000: acorr_ljungbox(ret, lags=[1000], return_df=True),
    4000: acorr_ljungbox(ret, lags=[4000], return_df=True),
    10000: acorr_ljungbox(ret, lags=[10000], return_df=True)
}

# Display results
for lag, result in ljung_box_results.items():
    print(f"\nLjung-Box Test Results (lag {lag}):")
    print(result)
# Out:
# <ipython-input-36-d71fb1cbca93>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp['log_return'] = np.log(sp['Close'] / sp['Close'].shift(1))
# Ljung-Box Test Results (lag 20):
#           lb_stat    lb_pvalue
# 20 315.3101622538 0.0000000000
#
# Ljung-Box Test Results (lag 100):
#            lb_stat    lb_pvalue
# 100 578.7269846709 0.0000000000
#
# Ljung-Box Test Results (lag 1000):
#              lb_stat    lb_pvalue
# 1000 2091.8048964745 0.0000000000
#
# Ljung-Box Test Results (lag 4000):
#              lb_stat    lb_pvalue
# 4000 6336.0786772650 0.0000000000
#
# Ljung-Box Test Results (lag 10000):
#                lb_stat    lb_pvalue
# 10000 13640.8957229218 0.0000000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# EWMA Parameters
lamb = 0.94     # Smoothing parameter
N = 75          # Window size for EWMA
w = (1 - lamb) * lamb ** np.arange(N)[::-1]  # EWMA weights

# Ensure the data doesn't have NaNs before splitting
sp = sp.dropna(subset=['realized_vol_D'])

# Split data into training (70%) and test (30%)
train_data = sp['realized_vol_D'].iloc[:int(len(sp) * 0.7)]
test_data = sp['realized_vol_D'].iloc[int(len(sp) * 0.7):]

# Initialize lists to store forecasted and actual values
forecasted_vol = []
actual_vol = []

# Rolling EWMA Forecast Loop
for i in range(len(test_data)):
    # Ensure we have enough data to forecast
    if len(train_data) < N:
        break

    # Get the last N values from training data
    last_N_data = train_data[-N:]

    # Forecast using EWMA on squared returns (variance)
    forecast_var = np.sum(w * last_N_data**2)
    forecast_vol_val = np.sqrt(forecast_var)

    # Append forecast and actual
    forecasted_vol.append(forecast_vol_val)
    actual_vol.append(test_data.iloc[i])

    # Update training data with the new observed value
    train_data = pd.concat([train_data, test_data.iloc[i:i+1]])

# Convert to Series and align indexes
actual_vol_series = pd.Series(actual_vol, index=test_data.index[:len(actual_vol)])
forecasted_vol_series = pd.Series(forecasted_vol, index=test_data.index[:len(forecasted_vol)])

# Drop any NaNs
valid_idx = (~actual_vol_series.isna()) & (~forecasted_vol_series.isna())
actual_vol_clean = actual_vol_series[valid_idx]
forecasted_vol_clean = forecasted_vol_series[valid_idx]

# Compute error metrics
mae = mean_absolute_error(actual_vol_clean, forecasted_vol_clean)
rmse = np.sqrt(mean_squared_error(actual_vol_clean, forecasted_vol_clean))

# Print MAE and RMSE
print(f"MAE (Mean Absolute Error): {mae:.6f}")
print(f"RMSE (Root Mean Squared Error): {rmse:.6f}")

# Plot actual vs. forecasted volatility
plt.figure(figsize=(12, 6))
plt.plot(actual_vol_clean.index, actual_vol_clean, label='Actual Realized Volatility', color='blue')
plt.plot(forecasted_vol_clean.index, forecasted_vol_clean, label='EWMA Forecasted Volatility', color='red', linestyle='--')

plt.title('Actual vs. EWMA Forecasted Volatility (Rolling Forecast)')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# MAE (Mean Absolute Error): 0.432779
# RMSE (Root Mean Squared Error): 0.663913

# %%
import seaborn as sns
import scipy.stats as stats

# Calculate forecast error (Actual - Forecast)
errors = actual_vol_clean - forecasted_vol_clean

# Plot histogram and KDE of the forecast errors
plt.figure(figsize=(10, 5))
sns.histplot(errors, kde=True, color='purple', bins=30)
plt.title("Distribution of Forecast Errors (Actual - Forecasted)")
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# Q-Q plot to assess normality
plt.figure(figsize=(6, 6))
stats.probplot(errors, dist="norm", plot=plt)
plt.title("Q-Q Plot of Forecast Errors")
plt.grid(True)
plt.tight_layout()
plt.show()

# Summary statistics
print("Forecast Error Summary:")
print(errors.describe())
# Out:
# Forecast Error Summary:
# count   28086.0000000000
# mean       -0.1187933072
# std         0.6532100354
# min        -4.6890467955
# 25%        -0.3758614745
# 50%        -0.0850176633
# 75%         0.1556303791
# max         4.5933211828
# dtype: float64

# %%
# !pip install arch
# Out:
# Collecting arch
#   Downloading arch-7.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from arch) (2.0.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from arch) (1.15.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from arch) (2.2.2)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.11/dist-packages (from arch) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->arch) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.12->arch) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->arch) (1.17.0)
# Downloading arch-7.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (985 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.3/985.3 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: arch
# Successfully installed arch-7.2.0

# %%
from arch import arch_model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# Use log returns
ret_pandas = sp['log_return']
realized_vol = sp['realized_vol_D']

# Ensure same length
ret_pandas = ret_pandas.iloc[-len(realized_vol):]
realized_vol = realized_vol.iloc[-len(ret_pandas):]

n = len(ret_pandas)
chunk_size = int(0.2 * n)
forecast_horizon = 1
max_start = n - chunk_size - forecast_horizon

random.seed(42)
start_indices = sorted(random.sample(range(0, max_start), 100))
rmse_list = []

for i, start in enumerate(start_indices):
    ret_chunk = ret_pandas.iloc[start:start + chunk_size]

    am = arch_model(ret_chunk, vol='GARCH', p=1, o=1, q=1, mean='Constant', dist='normal', rescale=True)
    result = am.fit(update_freq=5, disp='off')

    forecast = result.forecast(horizon=forecast_horizon)
    fvol = np.sqrt(forecast.variance.values[-1, :]) / result.scale

    # Actual realized volatility over next forecast_horizon
    actual_vol = realized_vol.iloc[start + chunk_size : start + chunk_size + forecast_horizon].values

    # Ensure shapes match
    if len(actual_vol) == forecast_horizon:
        rmse = np.sqrt(np.mean((actual_vol - fvol) ** 2))
        rmse_list.append((rmse, start))
        print(f"Sample {i+1} (Start Index {start}) - RMSE: {rmse:.4f}")
# Out:
# Sample 1 (Start Index 851) - RMSE: 0.4367
# Sample 2 (Start Index 3278) - RMSE: 0.4912
# Sample 3 (Start Index 3478) - RMSE: 1.0751
# Sample 4 (Start Index 3905) - RMSE: 1.1291
# Sample 5 (Start Index 4165) - RMSE: 0.2845
# Sample 6 (Start Index 4207) - RMSE: 0.0823
# Sample 7 (Start Index 5695) - RMSE: 0.2886
# Sample 8 (Start Index 6006) - RMSE: 0.2702
# Sample 9 (Start Index 7331) - RMSE: 0.2133
# Sample 10 (Start Index 8675) - RMSE: 0.1661
# Sample 11 (Start Index 9116) - RMSE: 0.3723
# Sample 12 (Start Index 9358) - RMSE: 0.2069
# Sample 13 (Start Index 10328) - RMSE: 0.9693
# Sample 14 (Start Index 10458) - RMSE: 0.2131
# Sample 15 (Start Index 11395) - RMSE: 0.2120
# Sample 16 (Start Index 12156) - RMSE: 0.6363
# Sample 17 (Start Index 12280) - RMSE: 0.1777
# Sample 18 (Start Index 12676) - RMSE: 0.7605
# Sample 19 (Start Index 13238) - RMSE: 0.3564
# Sample 20 (Start Index 13396) - RMSE: 0.2761
# Sample 21 (Start Index 13434) - RMSE: 0.2456
# Sample 22 (Start Index 14592) - RMSE: 0.9293
# Sample 23 (Start Index 16361) - RMSE: 0.2614
# Sample 24 (Start Index 18289) - RMSE: 0.2338
# Sample 25 (Start Index 18301) - RMSE: 0.2156
# Sample 26 (Start Index 18726) - RMSE: 0.6994
# Sample 27 (Start Index 20379) - RMSE: 0.1640
# Sample 28 (Start Index 20926) - RMSE: 0.2309
# Sample 29 (Start Index 21319) - RMSE: 0.9181
# Sample 30 (Start Index 21417) - RMSE: 2.5689
# Sample 31 (Start Index 22431) - RMSE: 0.1205
# Sample 32 (Start Index 25203) - RMSE: 0.1834
# Sample 33 (Start Index 26062) - RMSE: 0.2849
# Sample 34 (Start Index 27460) - RMSE: 1.5155
# Sample 35 (Start Index 27653) - RMSE: 0.2826
# Sample 36 (Start Index 27869) - RMSE: 0.2744
# Sample 37 (Start Index 28221) - RMSE: 1.3403
# Sample 38 (Start Index 28657) - RMSE: 1.1662
# Sample 39 (Start Index 28785) - RMSE: 1.2064
# Sample 40 (Start Index 28893) - RMSE: 0.1613
# Sample 41 (Start Index 29256) - RMSE: 0.7880
# Sample 42 (Start Index 29871) - RMSE: 0.8280
# Sample 43 (Start Index 30021) - RMSE: 1.6771
# Sample 44 (Start Index 30495) - RMSE: 0.6082
# Sample 45 (Start Index 30512) - RMSE: 0.2649
# Sample 46 (Start Index 32087) - RMSE: 0.8661
# Sample 47 (Start Index 32098) - RMSE: 0.9666
# Sample 48 (Start Index 32325) - RMSE: 0.3936
# Sample 49 (Start Index 34438) - RMSE: 0.4467
# Sample 50 (Start Index 34671) - RMSE: 0.1482
# Sample 51 (Start Index 34718) - RMSE: 0.2328
# Sample 52 (Start Index 34993) - RMSE: 0.1763
# Sample 53 (Start Index 35093) - RMSE: 0.0389
# Sample 54 (Start Index 35382) - RMSE: 0.8122
# Sample 55 (Start Index 36048) - RMSE: 0.4084
# Sample 56 (Start Index 36421) - RMSE: 0.0365
# Sample 57 (Start Index 36434) - RMSE: 0.2656
# Sample 58 (Start Index 36463) - RMSE: 0.6753
# Sample 59 (Start Index 37930) - RMSE: 0.2068
# Sample 60 (Start Index 38427) - RMSE: 0.5973
# Sample 61 (Start Index 41245) - RMSE: 0.1846
# Sample 62 (Start Index 41347) - RMSE: 0.9316
# Sample 63 (Start Index 42504) - RMSE: 0.6371
# Sample 64 (Start Index 44118) - RMSE: 0.1504
# Sample 65 (Start Index 44597) - RMSE: 0.5342
# Sample 66 (Start Index 45082) - RMSE: 1.0192
# Sample 67 (Start Index 46566) - RMSE: 0.0849
# Sample 68 (Start Index 47052) - RMSE: 0.2418
# Sample 69 (Start Index 47400) - RMSE: 1.6172
# Sample 70 (Start Index 47447) - RMSE: 0.3406
# Sample 71 (Start Index 47819) - RMSE: 0.0238
# Sample 72 (Start Index 48520) - RMSE: 0.2965
# Sample 73 (Start Index 49615) - RMSE: 0.1144
# Sample 74 (Start Index 49735) - RMSE: 0.2272
# Sample 75 (Start Index 49797) - RMSE: 0.4858
# Sample 76 (Start Index 49823) - RMSE: 0.1716
# Sample 77 (Start Index 51856) - RMSE: 0.1670
# Sample 78 (Start Index 52350) - RMSE: 0.1003
# Sample 79 (Start Index 52581) - RMSE: 0.6355
# Sample 80 (Start Index 54987) - RMSE: 0.5278
# Sample 81 (Start Index 55302) - RMSE: 0.1862
# Sample 82 (Start Index 55392) - RMSE: 0.4534
# Sample 83 (Start Index 56155) - RMSE: 0.0934
# Sample 84 (Start Index 58878) - RMSE: 0.2827
# Sample 85 (Start Index 59429) - RMSE: 1.7193
# Sample 86 (Start Index 60142) - RMSE: 1.9782
# Sample 87 (Start Index 60217) - RMSE: 1.4715
# Sample 88 (Start Index 60589) - RMSE: 3.3717
# Sample 89 (Start Index 65435) - RMSE: 0.9118
# Sample 90 (Start Index 66237) - RMSE: 3.4464
# Sample 91 (Start Index 70010) - RMSE: 0.4154
# Sample 92 (Start Index 70284) - RMSE: 1.2300
# Sample 93 (Start Index 70644) - RMSE: 0.1821
# Sample 94 (Start Index 71426) - RMSE: 0.1547
# Sample 95 (Start Index 71482) - RMSE: 0.2919
# Sample 96 (Start Index 72357) - RMSE: 0.1357
# Sample 97 (Start Index 73000) - RMSE: 2.2190
# Sample 98 (Start Index 73563) - RMSE: 0.0957
# Sample 99 (Start Index 73579) - RMSE: 0.1246
# Sample 100 (Start Index 74341) - RMSE: 0.0740

# %%
sorted_rmse = sorted(rmse_list, key=lambda x: x[0])
rmse_values = [x[0] for x in sorted_rmse]
plt.figure(figsize=(10, 6))
plt.hist(rmse_values, bins=20, edgecolor='black', color='skyblue')
plt.title('Distribution of RMSE (GARCH vs Realized Volatility)')
plt.xlabel('RMSE')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tqdm import tqdm

# Clean and prepare data
ret_pandas = sp['realized_vol_D'].replace([np.inf, -np.inf], np.nan).dropna()
train_size = int(len(ret_pandas) * 0.7)
train_data = ret_pandas.iloc[:train_size]
test_data = ret_pandas.iloc[train_size:]

# Settings
scale_factor = 1e4
rolling_window_size = 250  # use a fixed-size window
refit_frequency = 5        # refit model every 5 steps

forecasted_vol = []
actual_vol = []
rolling_window = list(train_data[-rolling_window_size:])  # fixed window

# Initial model fit
model = arch_model(np.array(rolling_window) * scale_factor,
                   vol='APARCH', p=1, q=1, power=2.0,
                   mean='Constant', dist='normal')
res = model.fit(disp='off')

for i in tqdm(range(len(test_data)), desc="Rolling APARCH Forecasting"):
    # Refit the model only every `refit_frequency` steps
    if i % refit_frequency == 0:
        model = arch_model(np.array(rolling_window) * scale_factor,
                           vol='APARCH', p=1, q=1, power=2.0,
                           mean='Constant', dist='normal')
        res = model.fit(disp='off')

    # Forecast next day's volatility
    forecast = res.forecast(horizon=1)
    fcast_vol = np.sqrt(forecast.variance.values[-1][0]) / scale_factor
    forecasted_vol.append(fcast_vol)

    # Store actual volatility
    actual_value = test_data.iloc[i]
    actual_vol.append(actual_value)

    # Update the rolling window
    rolling_window.append(actual_value)
    if len(rolling_window) > rolling_window_size:
        rolling_window.pop(0)

# Compute error metrics
mae = mean_absolute_error(actual_vol, forecasted_vol)
rmse = np.sqrt(mean_squared_error(actual_vol, forecasted_vol))

print(f"\nMean Absolute Error (MAE): {mae:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(test_data.index, actual_vol, label='Actual Realized Volatility', color='blue')
plt.plot(test_data.index, forecasted_vol, label='APARCH Forecasted Volatility', color='red', linestyle='--')
plt.title('Rolling APARCH Forecast vs Actual Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25456/28086 [14:33<01:05, 40.43it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.152e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25461/28086 [14:33<01:08, 38.26it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.317e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.386e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25471/28086 [14:33<00:55, 46.79it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.396e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.431e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25481/28086 [14:34<00:53, 49.12it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.472e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.475e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25491/28086 [14:34<00:47, 54.26it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.454e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25497/28086 [14:34<00:47, 54.91it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.441e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25503/28086 [14:34<00:47, 54.64it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.486e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25509/28086 [14:34<00:49, 52.36it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.606e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25515/28086 [14:34<01:03, 40.22it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.683e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25520/28086 [14:34<01:05, 39.10it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.689e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25525/28086 [14:35<01:05, 39.34it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.723e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25530/28086 [14:35<01:06, 38.60it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.764e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25534/28086 [14:35<01:10, 36.43it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.765e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25538/28086 [14:35<01:11, 35.86it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.732e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25542/28086 [14:35<01:15, 33.73it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.682e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25546/28086 [14:35<01:20, 31.53it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.667e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25551/28086 [14:35<01:20, 31.41it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.621e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25559/28086 [14:36<00:59, 42.42it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.563e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.509e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25566/28086 [14:36<01:03, 39.91it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.476e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25571/28086 [14:36<01:06, 38.01it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.457e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25576/28086 [14:36<01:19, 31.64it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.433e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25581/28086 [14:36<01:31, 27.37it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.415e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25586/28086 [14:36<01:24, 29.45it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.427e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25591/28086 [14:37<01:26, 28.70it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.481e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25596/28086 [14:37<01:25, 29.20it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.519e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25601/28086 [14:37<01:25, 29.01it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.514e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25606/28086 [14:37<01:29, 27.60it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.484e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25611/28086 [14:37<01:39, 24.94it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.432e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25616/28086 [14:38<01:50, 22.37it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.361e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25621/28086 [14:38<01:48, 22.75it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.324e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████ | 25626/28086 [14:38<01:51, 22.15it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.287e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25631/28086 [14:38<01:59, 20.60it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.208e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25636/28086 [14:39<01:55, 21.23it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.127e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25641/28086 [14:39<01:46, 23.04it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.097e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25646/28086 [14:39<01:45, 23.03it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.114e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25651/28086 [14:39<01:41, 24.08it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.1e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25656/28086 [14:39<01:41, 24.00it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.075e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25661/28086 [14:40<01:42, 23.74it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.088e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25666/28086 [14:40<01:54, 21.06it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.139e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25671/28086 [14:40<01:52, 21.50it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.168e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25676/28086 [14:40<01:43, 23.38it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.14e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25681/28086 [14:41<01:37, 24.66it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.141e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25686/28086 [14:41<01:28, 27.05it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.209e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25691/28086 [14:41<01:19, 30.23it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.064e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  91%|█████████▏| 25696/28086 [14:41<01:15, 31.48it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.585e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25701/28086 [14:41<01:15, 31.51it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.664e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25711/28086 [14:41<01:05, 36.26it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.558e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25716/28086 [14:41<01:05, 36.13it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.533e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25721/28086 [14:42<01:09, 34.20it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.504e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25726/28086 [14:42<01:11, 32.83it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.465e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25731/28086 [14:42<01:07, 34.72it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.442e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25736/28086 [14:42<01:08, 34.45it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.462e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25741/28086 [14:42<01:07, 34.80it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.491e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25746/28086 [14:42<01:07, 34.72it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.508e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25751/28086 [14:43<01:14, 31.41it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.431e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25756/28086 [14:43<01:25, 27.32it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.256e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25761/28086 [14:43<01:22, 28.11it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.13e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25766/28086 [14:43<01:26, 26.97it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.119e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25771/28086 [14:43<01:24, 27.41it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.249e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25776/28086 [14:44<01:17, 29.77it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.614e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25781/28086 [14:44<01:15, 30.53it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.137e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25786/28086 [14:44<01:16, 29.91it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.562e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25791/28086 [14:44<01:08, 33.44it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.693e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25796/28086 [14:44<01:10, 32.65it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.672e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25801/28086 [14:44<01:07, 33.65it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.706e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25806/28086 [14:44<01:19, 28.76it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.741e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25811/28086 [14:45<01:14, 30.58it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.753e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25816/28086 [14:45<01:17, 29.40it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.731e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25821/28086 [14:45<01:12, 31.09it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.67e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25826/28086 [14:45<01:11, 31.83it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.639e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25831/28086 [14:45<01:09, 32.43it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.723e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25836/28086 [14:45<01:05, 34.43it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.881e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25841/28086 [14:46<01:06, 33.85it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.987e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25846/28086 [14:46<01:05, 33.98it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.028e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25851/28086 [14:46<01:04, 34.87it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.039e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25856/28086 [14:46<01:07, 32.88it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.041e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25861/28086 [14:46<01:05, 34.10it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.072e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25866/28086 [14:46<01:05, 34.11it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.091e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25871/28086 [14:46<01:08, 32.14it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.073e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25876/28086 [14:47<01:04, 34.15it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.046e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25881/28086 [14:47<01:01, 35.62it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.064e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25886/28086 [14:47<01:06, 33.14it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.068e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting:  92%|█████████▏| 25891/28086 [14:47<01:04, 34.09it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.043e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# ...
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27951/28086 [16:00<00:04, 30.34it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.702e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27956/28086 [16:00<00:04, 29.41it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.605e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27961/28086 [16:00<00:04, 27.59it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.511e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27966/28086 [16:00<00:04, 27.77it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.509e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27971/28086 [16:00<00:04, 27.51it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.498e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27976/28086 [16:01<00:04, 26.73it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.522e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27981/28086 [16:01<00:03, 28.38it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.515e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27986/28086 [16:01<00:04, 21.94it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.473e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27991/28086 [16:01<00:03, 24.97it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.457e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 27996/28086 [16:01<00:03, 28.32it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.338e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28001/28086 [16:02<00:03, 27.35it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.8e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28006/28086 [16:02<00:02, 28.30it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.136e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28011/28086 [16:02<00:02, 25.92it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.997e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28016/28086 [16:02<00:02, 25.71it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.023e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.831e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28026/28086 [16:02<00:01, 31.41it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.582e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28031/28086 [16:03<00:01, 28.36it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.45e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28036/28086 [16:03<00:01, 25.89it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.398e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.393e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28046/28086 [16:03<00:01, 36.78it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.389e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28051/28086 [16:03<00:01, 31.26it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.39e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28056/28086 [16:03<00:01, 27.17it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.393e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28061/28086 [16:04<00:00, 26.11it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.388e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28066/28086 [16:04<00:00, 25.91it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.339e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28071/28086 [16:04<00:00, 25.53it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.338e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28076/28086 [16:04<00:00, 25.56it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.329e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 9. The message is:
# Iteration limit reached
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|█████████▉| 28081/28086 [16:05<00:00, 24.50it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.315e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Rolling APARCH Forecasting: 100%|██████████| 28086/28086 [16:05<00:00, 29.10it/s]
# Mean Absolute Error (MAE): 0.499340
# Root Mean Squared Error (RMSE): 0.710411

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tqdm import tqdm

# --- Step 1: Clean & prepare data ---
ret_pandas = sp['realized_vol_D'].replace([np.inf, -np.inf], np.nan).dropna()
train_size = int(0.7 * len(ret_pandas))
train_data = ret_pandas[:train_size]
test_data = ret_pandas[train_size:]

# Scale data
scale = 1e4
train_data_scaled = train_data * scale
test_data_scaled = test_data * scale

# --- Settings ---
rolling_window_size = 250
refit_every = 10
num_simulations = 1
max_test_points = 300  # cut for speed during development

mae_list = []
rmse_list = []

# --- Step 2: Simulation Loop ---
for sim in tqdm(range(num_simulations), desc="Simulating FIE-GARCH Forecasting"):
    start_idx = np.random.randint(0, int(len(train_data_scaled) * 0.5))
    selected_chunk = train_data_scaled.iloc[start_idx:start_idx + rolling_window_size].copy()

    simulated_forecasted_vol = []
    simulated_actual_vol = []

    # Initial model fit
    model = arch_model(selected_chunk,
                       vol='FIGARCH', p=1, q=1,
                       mean='Constant', dist='normal')
    res = model.fit(disp='off')

    for i in range(min(len(test_data_scaled), max_test_points)):
        # Refit every `refit_every` steps
        if i % refit_every == 0:
            try:
                model = arch_model(selected_chunk, vol='FIGARCH', p=1, q=1,
                                   mean='Constant', dist='normal')
                res = model.fit(disp='off')
            except Exception:
                pass  # keep old model if fails

        try:
            forecast = res.forecast(horizon=1)
            fcast_var = forecast.variance.values[-1][0]
            fcast_vol = np.sqrt(fcast_var) / scale
        except:
            fcast_vol = selected_chunk.iloc[-1] / scale

        simulated_forecasted_vol.append(fcast_vol)
        actual_vol_point = test_data.iloc[i]
        simulated_actual_vol.append(actual_vol_point)

        # Update rolling window
        selected_chunk = pd.concat([selected_chunk, pd.Series(test_data_scaled.iloc[i])])
        if len(selected_chunk) > rolling_window_size:
            selected_chunk = selected_chunk[-rolling_window_size:]

    # --- Step 3: Evaluation ---
    mae = mean_absolute_error(simulated_actual_vol, simulated_forecasted_vol)
    rmse = np.sqrt(mean_squared_error(simulated_actual_vol, simulated_forecasted_vol))
    mae_list.append(mae)
    rmse_list.append(rmse)

# --- Step 4: Report Performance ---
print(f"\nMean MAE (FIE-GARCH): {np.mean(mae_list):.6f} ± {np.std(mae_list):.6f}")
print(f"Mean RMSE (FIE-GARCH): {np.mean(rmse_list):.6f} ± {np.std(rmse_list):.6f}")

# --- Step 5: Plotting One Simulation ---
plt.figure(figsize=(12, 6))
plt.plot(test_data.index[:max_test_points], simulated_actual_vol, label='Actual Volatility', color='blue')
plt.plot(test_data.index[:max_test_points], simulated_forecasted_vol, label='FIE-GARCH Forecasted Volatility', color='green', linestyle='--')
plt.title('FIE-GARCH Forecast vs Actual Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Simulating FIE-GARCH Forecasting:   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.373e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.373e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.401e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.476e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.432e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.47e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.421e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.444e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.439e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.432e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.421e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.436e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.455e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.367e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.072e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.39e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.596e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.599e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.555e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.259e+06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.123e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.212e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.182e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.218e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.241e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.2e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.153e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.13e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.079e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.145e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.369e+07. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 0.01 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Simulating FIE-GARCH Forecasting: 100%|██████████| 1/1 [00:06<00:00,  6.88s/it]
# Mean MAE (FIE-GARCH): 0.407229 ± 0.000000
# Mean RMSE (FIE-GARCH): 0.520109 ± 0.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_absolute_error, mean_squared_error

# --- Prepare Data ---
ret_pandas = sp['realized_vol_D'].replace([np.inf, -np.inf], np.nan).dropna()

train_size = int(len(ret_pandas) * 0.7)
train_data = ret_pandas[:train_size]
test_data = ret_pandas[train_size:]

# Fit AR model (no scaling)
model = AutoReg(train_data, lags=1)  # AR(1) model
res = model.fit()

# Forecast using the fitted AR model
forecasted_vol = res.predict(start=len(train_data), end=len(train_data) + len(test_data) - 1, dynamic=False)

# Compute error metrics
mae = mean_absolute_error(test_data, forecasted_vol)
rmse = np.sqrt(mean_squared_error(test_data, forecasted_vol))

print(f"\nMean Absolute Error (MAE): {mae:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(test_data.index, test_data, label='Actual Realized Volatility', color='blue')
plt.plot(test_data.index, forecasted_vol, label='AR Forecasted Volatility', color='red', linestyle='--')
plt.title('AR Model Forecast vs Actual Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# Mean Absolute Error (MAE): 0.626388
# Root Mean Squared Error (RMSE): 1.051566

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from arch import arch_model
from statsmodels.tsa.ar_model import AutoReg
from arch.__future__ import reindexing  # future-proof indexing

# Load your data
# Replace this line with the actual loading method for your data
# Example: sp = pd.read_csv("your_data.csv", parse_dates=True, index_col='Date')
realized_vol = sp['realized_vol_D'].dropna()
y = realized_vol.copy()
n_train = int(len(y) * 0.998)

# %%
# EWMA Volatility
def ewma_volatility(series, lambda_=0.94):
    ewma = []
    prev = series.var()
    for r in series:
        var = lambda_ * prev + (1 - lambda_) * r**2
        ewma.append(np.sqrt(var))
        prev = var
    return pd.Series(ewma, index=series.index)

# Containers for forecasts
rv_ewma = []
rv_gjr_garch = []
rv_aparch = []
rv_figarch = []
rv_arrv = []

# %%
for i in tqdm(range(n_train, len(y)), desc="Rolling Forecast"):
    train = y[:i]

    # EWMA
    try:
        ewma = ewma_volatility(train)
        rv_ewma.append(ewma.iloc[-1])
    except:
        rv_ewma.append(np.nan)

    # GJR-GARCH(1,1,1)
    try:
        gjr = arch_model(train, vol='GARCH', p=1, o=1, q=1, dist='normal')
        res_gjr = gjr.fit(disp='off')
        forecast = res_gjr.forecast(horizon=1).variance.values[-1, 0]
        rv_gjr_garch.append(np.sqrt(forecast))
    except:
        rv_gjr_garch.append(np.nan)

    # APARCH(1,1)
    try:
        aparch = arch_model(train, vol='APARCH', p=1, q=1, dist='normal')
        res_aparch = aparch.fit(disp='off')
        forecast = res_aparch.forecast(horizon=1).variance.values[-1, 0]
        rv_aparch.append(np.sqrt(forecast))
    except:
        rv_aparch.append(np.nan)

    # FIGARCH(1,d,1)
    try:
        figarch = arch_model(train, vol='FIGARCH', p=1, q=1, dist='normal')
        res_figarch = figarch.fit(disp='off')
        forecast = res_figarch.forecast(horizon=1).variance.values[-1, 0]
        rv_figarch.append(np.sqrt(forecast))
    except:
        rv_figarch.append(np.nan)

    # AR-RV
    try:
        ar_model = AutoReg(train, lags=1).fit()
        forecast = ar_model.predict(start=len(train), end=len(train))
        rv_arrv.append(float(forecast))
    except:
        rv_arrv.append(np.nan)
# Out:
# Rolling Forecast:   0%|          | 0/188 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   1%|          | 1/188 [00:35<1:51:03, 35.63s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   1%|          | 2/188 [01:14<1:55:58, 37.41s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   2%|▏         | 3/188 [01:50<1:54:01, 36.98s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   2%|▏         | 4/188 [02:44<2:14:05, 43.73s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   3%|▎         | 5/188 [03:17<2:01:32, 39.85s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   3%|▎         | 6/188 [03:45<1:48:10, 35.66s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   4%|▎         | 7/188 [04:16<1:42:48, 34.08s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   4%|▍         | 8/188 [04:46<1:38:45, 32.92s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   5%|▍         | 9/188 [05:37<1:54:35, 38.41s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   5%|▌         | 10/188 [06:31<2:08:23, 43.28s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   6%|▌         | 11/188 [07:16<2:09:36, 43.93s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   6%|▋         | 12/188 [08:08<2:15:37, 46.24s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   7%|▋         | 13/188 [08:42<2:04:26, 42.67s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   7%|▋         | 14/188 [09:17<1:57:16, 40.44s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   8%|▊         | 15/188 [09:48<1:47:46, 37.38s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   9%|▊         | 16/188 [10:17<1:40:06, 34.92s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:   9%|▉         | 17/188 [10:59<1:45:28, 37.01s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  10%|▉         | 18/188 [11:19<1:30:43, 32.02s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  10%|█         | 19/188 [11:56<1:34:23, 33.51s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  11%|█         | 20/188 [12:36<1:39:28, 35.53s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  11%|█         | 21/188 [13:00<1:29:04, 32.00s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  12%|█▏        | 22/188 [13:39<1:34:03, 34.00s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  12%|█▏        | 23/188 [14:30<1:48:01, 39.28s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  13%|█▎        | 24/188 [15:07<1:44:48, 38.34s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  13%|█▎        | 25/188 [15:51<1:49:18, 40.24s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  14%|█▍        | 26/188 [16:41<1:56:22, 43.10s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  14%|█▍        | 27/188 [17:30<2:00:20, 44.85s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  15%|█▍        | 28/188 [18:17<2:01:43, 45.64s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# ...
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  45%|████▌     | 85/188 [52:54<1:00:52, 35.46s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  46%|████▌     | 86/188 [53:30<1:00:43, 35.72s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  46%|████▋     | 87/188 [54:11<1:02:34, 37.17s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  47%|████▋     | 88/188 [54:52<1:03:53, 38.34s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  47%|████▋     | 89/188 [55:39<1:07:42, 41.03s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  48%|████▊     | 90/188 [56:31<1:12:11, 44.20s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  48%|████▊     | 91/188 [57:04<1:05:53, 40.76s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  49%|████▉     | 92/188 [57:49<1:07:38, 42.28s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  49%|████▉     | 93/188 [58:29<1:05:31, 41.39s/it]/usr/local/lib/python3.11/dist-packages/arch/univariate/base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  50%|█████     | 94/188 [59:09<1:04:23, 41.10s/it]/usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:308: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <ipython-input-50-8cfa6eeadca0>:42: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rv_arrv.append(float(forecast))
# Rolling Forecast:  51%|█████     | 95/188 [59:46<1:01:40, 39.79s/it]

# %%
# Create DataFrame
forecast_index = y.index[n_train:]
df_results = pd.DataFrame({
    'actual': y[n_train:].values,
    'EWMA': rv_ewma,
    'GJR-GARCH': rv_gjr_garch,
    'APARCH': rv_aparch,
    'FIGARCH': rv_figarch,
    'AR-RV': rv_arrv
}, index=forecast_index)

# R² OS Function
def r2_os(y_true, y_pred, benchmark):
    num = np.sum((y_true - y_pred)**2)
    denom = np.sum((y_true - benchmark)**2)
    return 1 - num / denom

# Benchmark = Historical mean of training set
benchmark = np.mean(y[:n_train])

# R² OS Outputs
print("R² OS (EWMA):", r2_os(df_results['actual'], df_results['EWMA'], benchmark))
print("R² OS (GJR-GARCH):", r2_os(df_results['actual'], df_results['GJR-GARCH'], benchmark))
print("R² OS (APARCH):", r2_os(df_results['actual'], df_results['APARCH'], benchmark))
print("R² OS (FIGARCH):", r2_os(df_results['actual'], df_results['FIGARCH'], benchmark))
print("R² OS (AR-RV):", r2_os(df_results['actual'], df_results['AR-RV'], benchmark))

# %%
import matplotlib.pyplot as plt

plt.style.use('classic')  # or try 'ggplot', 'bmh', 'fivethirtyeight'

plt.figure(figsize=(14, 8))

# Plot actual vs forecasts
plt.plot(df_results.index, df_results['actual'], label='Actual Realized Volatility', linewidth=2, color='black')
plt.plot(df_results.index, df_results['EWMA'], label='EWMA', linestyle='--')
plt.plot(df_results.index, df_results['GJR-GARCH'], label='GJR-GARCH(1,1,1)', linestyle='--')
plt.plot(df_results.index, df_results['APARCH'], label='APARCH(1,1)', linestyle='--')
plt.plot(df_results.index, df_results['FIGARCH'], label='FIGARCH(1,d,1)', linestyle='--')
plt.plot(df_results.index, df_results['AR-RV'], label='AR-RV(1)', linestyle='--')

# Final plot settings
plt.title('Out-of-Sample Volatility Forecasts vs Realized Volatility')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm
import pandas as pd

def run_regression(y, X, label):
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    print(f"\n--- Regression for {label} ---")
    print(model.summary())
    return model

# Convert forecast lists to pandas Series with proper indexing
index = y[n_train:].index  # ensure alignment with actual values

df_results = pd.DataFrame({
    'actual': y[n_train:].values,
    'EWMA': pd.Series(rv_ewma, index=index),
    'GJR-GARCH': pd.Series(rv_gjr_garch, index=index),
    'APARCH': pd.Series(rv_aparch, index=index),
    'FIGARCH': pd.Series(rv_figarch, index=index),
    'AR-RV': pd.Series(rv_arrv, index=index)
}, index=index)

# Rename columns for regression
df_reg = df_results.rename(columns={
    'actual': 'RV_Actual',
    'EWMA': 'RV_EWMA',
    'GJR-GARCH': 'RV_GARCH',
    'APARCH': 'RV_APARCH',
    'FIGARCH': 'RV_FIGARCH',
    'AR-RV': 'RV_ARRV'
})

# Drop any rows with NaNs
df_reg_clean = df_reg.dropna()

# Run individual regressions
run_regression(df_reg_clean['RV_Actual'], df_reg_clean['RV_EWMA'], 'EWMA')
run_regression(df_reg_clean['RV_Actual'], df_reg_clean['RV_GARCH'], 'GARCH')
run_regression(df_reg_clean['RV_Actual'], df_reg_clean['RV_APARCH'], 'APARCH')
run_regression(df_reg_clean['RV_Actual'], df_reg_clean['RV_FIGARCH'], 'FIGARCH')
run_regression(df_reg_clean['RV_Actual'], df_reg_clean['RV_ARRV'], 'ARRV')

# Run joint regression
run_regression(
    df_reg_clean['RV_Actual'],
    df_reg_clean[['RV_EWMA', 'RV_GARCH', 'RV_APARCH', 'RV_FIGARCH', 'RV_ARRV']],
    'All Models'
)
